# %%
import gym
import numpy as np
import time

# install gym, numpy, and pygame to run this code

# %%
# Instantiate the environment
env = gym.make('CartPole-v1', render_mode='human')

# %%
# Number of episodes and time steps
episodeNumber = 10000
timeSteps = 100

# Loop over episodes
for episodeIndex in range(episodeNumber):
    # Reset the environment
    initial_state = env.reset()
    print("Episode: ", episodeIndex)
    env.render()
    appendedObservations = []
    for timeIndex in range(timeSteps):
        print("Time step: ", timeIndex)
        # Pick a random action from the action space
        action = env.action_space.sample()

        # Get the observation, reward, done, and info from the environment
        # Observation: For the CartPole environment, it is a 4-dimensional vector containing the position of the cart, the velocity of the cart, the angle of the pole, and the angular velocity of the pole
        # Reward: For the CartPole environment, it is a scalar value representing the reward for the current time step
        # Done: A boolean value indicating whether the episode has ended
        # Truncated: A boolean value indicating whether the episode was truncated (meaning that the maximum number of time steps was reached)
        # Info: A dictionary containing additional information about the environment
        observation, reward, done, truncated, info = env.step(action)
        appendedObservations.append(observation)
        env.render()
        time.sleep(0.01)
        if done:
            # If the episode is done, break out of the loop
            time.sleep(1)
            break
# Out:
# Episode:  0
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# c:\Users\Tanay\AppData\Local\Programs\Python\Python312\Lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Episode:  1
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Episode:  2
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Episode:  3
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Episode:  4
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Time step:  20
# Time step:  21
# Time step:  22
# Time step:  23
# Time step:  24
# Time step:  25
# Time step:  26
# Time step:  27
# Time step:  28
# Time step:  29
# Time step:  30
# Time step:  31
# Time step:  32
# Time step:  33
# Time step:  34
# Time step:  35
# Episode:  5
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Time step:  20
# Time step:  21
# Time step:  22
# Time step:  23
# Time step:  24
# Time step:  25
# Time step:  26
# Episode:  6
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Episode:  7
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Time step:  20
# Time step:  21
# Time step:  22
# Time step:  23
# Time step:  24
# Time step:  25
# Time step:  26
# Time step:  27
# Time step:  28
# Time step:  29
# Time step:  30
# Time step:  31
# Time step:  32
# Time step:  33
# Episode:  8
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Episode:  9
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Episode:  10
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Episode:  11
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Time step:  20
# Time step:  21
# Time step:  22
# Time step:  23
# Time step:  24
# Time step:  25
# Time step:  26
# Time step:  27
# Time step:  28
# Time step:  29
# Time step:  30
# Time step:  31
# Episode:  12
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Time step:  20
# Time step:  21
# Time step:  22
# Episode:  13
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Time step:  20
# Time step:  21
# Episode:  14
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Time step:  20
# Time step:  21
# Time step:  22
# Time step:  23
# Time step:  24
# Episode:  15
# Time step:  0
# Time step:  1
# Time step:  2
# Time step:  3
# Time step:  4
# Time step:  5
# Time step:  6
# Time step:  7
# Time step:  8
# Time step:  9
# Time step:  10
# Time step:  11
# Time step:  12
# Time step:  13
# Time step:  14
# Time step:  15
# Time step:  16
# Time step:  17
# Time step:  18
# Time step:  19
# Time step:  20
# Time step:  21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 15
#      13 appendedObservations.append(observation)
#      14 env.render()
# ---> 15 time.sleep(0.01)
#      16 if done:
#      17     time.sleep(1)
#
# KeyboardInterrupt:

# %%
# Interrupt the kernel and run this cell again to close the environment
env.close()
